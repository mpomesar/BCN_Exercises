# %% [markdown]
# <a href="https://colab.research.google.com/github/mpomesar/BCN_Exercises/blob/main/BCN_Rent01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %% [markdown]
# # 1.0 Call

# %%
# 1.0 Call
endpoint="https://opendata-ajuntament.barcelona.cat/data/api/action/datastore_search?resource_id=e96bf614-467b-40ab-91b9-e48a616ea775"
response=requests.get(url=endpoint)

# %% [markdown]
# # 2.0 Deal with response

# %%
# 2.0 Deal with response
body=response.json()

listFields=body.get("result")["fields"]
columnsList=[i["id"] for i in listFields]

listResults=body.get("result")["records"]
corpusList=[]
for idx, item in enumerate(listResults):
    corpusList.append([])
    for head in columnsList:
        corpusList[idx].append(item[head])

frame=pd.DataFrame(corpusList,columns=columnsList)
frame=frame[frame["Preu"]!="NA"]
frame=frame.astype({"Preu":"float"})

# %%
frame
# Out:
#     _id   Any Trimestre Codi_Districte        Nom_Districte Codi_Barri  \
# 0     1  2022         1              1         Ciutat Vella          1
# 1     2  2022         1              1         Ciutat Vella          2
# 2     3  2022         1              1         Ciutat Vella          3
# 3     4  2022         1              1         Ciutat Vella          4
# 4     5  2022         1              2             Eixample          5
# ..  ...   ...       ...            ...                  ...        ...
# 95   96  2022         1              5  Sarrià-Sant Gervasi         23
# 96   97  2022         1              5  Sarrià-Sant Gervasi         24
# 97   98  2022         1              5  Sarrià-Sant Gervasi         25
# 98   99  2022         1              5  Sarrià-Sant Gervasi         26
# 99  100  2022         1              5  Sarrià-Sant Gervasi         27
#
#                                 Nom_Barri  \
# 0                                el Raval
# 1                          el Barri Gòtic
# 2                          la Barceloneta
# 3   Sant Pere, Santa Caterina i la Ribera
# 4                           el Fort Pienc
# ..                                    ...
# 95                                 Sarrià
# 96                        les Tres Torres
# 97             Sant Gervasi - la Bonanova
# 98                 Sant Gervasi - Galvany
# 99                   el Putxet i el Farró
#
#                                   Lloguer_mitja    Preu
# 0             Lloguer mitjà mensual (Euros/mes)   917.0
# 1             Lloguer mitjà mensual (Euros/mes)  1181.6
# 2             Lloguer mitjà mensual (Euros/mes)   999.8
# 3             Lloguer mitjà mensual (Euros/mes)  1022.8
# 4             Lloguer mitjà mensual (Euros/mes)   957.9
# ..                                          ...     ...
# 95  Lloguer mitjà per superfície (Euros/m2 mes)    17.5
# 96  Lloguer mitjà per superfície (Euros/m2 mes)    17.6
# 97  Lloguer mitjà per superfície (Euros/m2 mes)    14.2
# 98  Lloguer mitjà per superfície (Euros/m2 mes)    14.5
# 99  Lloguer mitjà per superfície (Euros/m2 mes)    14.8
#
# [93 rows x 9 columns]

# %%
frame.groupby(["Nom_Districte","Lloguer_mitja"]).mean(["Preu"]).sort_values(["Lloguer_mitja"])
# Out:
#                                                                        _id  \
# Nom_Districte       Lloguer_mitja
# Ciutat Vella        Lloguer mitjà mensual (Euros/mes)             2.500000
# Eixample            Lloguer mitjà mensual (Euros/mes)             7.500000
# Gràcia              Lloguer mitjà mensual (Euros/mes)            30.000000
# Horta-Guinardó      Lloguer mitjà mensual (Euros/mes)            37.600000
# Les Corts           Lloguer mitjà mensual (Euros/mes)            20.000000
# Nou Barris          Lloguer mitjà mensual (Euros/mes)            49.300000
# Sant Andreu         Lloguer mitjà mensual (Euros/mes)            60.333333
# Sant Martí          Lloguer mitjà mensual (Euros/mes)            68.500000
# Sants-Montjuïc      Lloguer mitjà mensual (Euros/mes)            14.857143
# Sarrià-Sant Gervasi Lloguer mitjà mensual (Euros/mes)            24.500000
# Ciutat Vella        Lloguer mitjà per superfície (Euros/m2 mes)  75.500000
# Eixample            Lloguer mitjà per superfície (Euros/m2 mes)  80.500000
# Les Corts           Lloguer mitjà per superfície (Euros/m2 mes)  93.000000
# Sants-Montjuïc      Lloguer mitjà per superfície (Euros/m2 mes)  87.857143
# Sarrià-Sant Gervasi Lloguer mitjà per superfície (Euros/m2 mes)  97.500000
#
#                                                                         Preu
# Nom_Districte       Lloguer_mitja
# Ciutat Vella        Lloguer mitjà mensual (Euros/mes)            1030.300000
# Eixample            Lloguer mitjà mensual (Euros/mes)            1058.650000
# Gràcia              Lloguer mitjà mensual (Euros/mes)             915.180000
# Horta-Guinardó      Lloguer mitjà mensual (Euros/mes)             762.560000
# Les Corts           Lloguer mitjà mensual (Euros/mes)            1221.133333
# Nou Barris          Lloguer mitjà mensual (Euros/mes)             653.780000
# Sant Andreu         Lloguer mitjà mensual (Euros/mes)             752.483333
# Sant Martí          Lloguer mitjà mensual (Euros/mes)             929.590000
# Sants-Montjuïc      Lloguer mitjà mensual (Euros/mes)             837.300000
# Sarrià-Sant Gervasi Lloguer mitjà mensual (Euros/mes)            1281.166667
# Ciutat Vella        Lloguer mitjà per superfície (Euros/m2 mes)    17.325000
# Eixample            Lloguer mitjà per superfície (Euros/m2 mes)    14.266667
# Les Corts           Lloguer mitjà per superfície (Euros/m2 mes)    14.366667
# Sants-Montjuïc      Lloguer mitjà per superfície (Euros/m2 mes)    13.071429
# Sarrià-Sant Gervasi Lloguer mitjà per superfície (Euros/m2 mes)    15.150000
